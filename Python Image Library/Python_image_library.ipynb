# %%
import numpy as np
import matplotlib.pyplot as plt 
from PIL import Image

# %%
img=Image.open("nature-image.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x630>

# %%
img.getbbox()
# Out:
# (0, 0, 1200, 630)

# %%
img.format
# Out:
# 'JPEG'

# %%
img.size
# Out:
# (1200, 630)

# %%
img.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x630>

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x630>

# %%
img.resize((300,300))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
img1=img.copy()

# %%
img1=img1.resize((300,300))

# %%
img1
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
img.paste(img1) #img1 pasted on base img

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x630>

# %%
cropping= img1.crop((0,12,100,100))

# %%
cropping
# Out:
# <PIL.Image.Image image mode=RGB size=100x88>

# %%
flip=img.transpose(Image.FLIP_LEFT_RIGHT)
flip
# Out:
# <PIL.Image.Image image mode=RGB size=1200x630>

# %%
flip1=img.transpose(Image.FLIP_TOP_BOTTOM)
flip1
# Out:
# <PIL.Image.Image image mode=RGB size=1200x630>

# %%
from PIL import ImageFilter
imgf=img.filter(ImageFilter.BLUR)
imgf.show()

# %%
imgf1=img.filter(ImageFilter.CONTOUR)
imgf1.show()

# %%
imgf2=img.filter(ImageFilter.EMBOSS)
imgf2.show()

# %%
imgf3=img.filter(ImageFilter.EDGE_ENHANCE)
imgf3.show()

# %%
imgf=img.filter(ImageFilter.SMOOTH)
imgf.show()

# %%
imagesplit=Image.Image.split(img)
imagesplit[0].show()
imagesplit[0].show()
imagesplit[0].show()

# %%
img_array=np.array(img)

# %%
plt.imshow(img_array[:,:,0],cmap='gray')

# %%
plt.imshow(img_array[:,:,1],cmap='gray')

# %%
plt.imshow(img_array[:,:,2],cmap='gray')
